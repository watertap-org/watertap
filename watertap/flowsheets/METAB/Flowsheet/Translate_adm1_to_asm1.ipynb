# %% [markdown]
# # This notebook is used to transalte adm1 pro to asm1 prom

# %%
import pandas as pd
def read_adm1_data(file = 'influent_to_wwtp.csv'):
    df = pd.read_csv(file, index_col =  0)
    return df

# %%
df = read_adm1_data()
df.head()
# Out:
#        S_su      S_aa       S_fa      S_va      S_bu     S_pro       S_ac  \
# 1  0.731084  0.752787  20.490541  1.254585  1.590597  1.766505  13.075181
# 2  0.790039  0.802502  21.046698  1.360776  1.724301  1.970121  13.572688
# 3  2.440719  1.912096  29.209465  3.663656  4.753397  5.722872  21.253652
# 4  1.969023  1.636827  27.625613  3.122116  4.006898  5.012716  19.372994
# 5  0.622173  0.657064  19.328076  1.053645  1.337960  1.407006  12.572153
#
#        S_h2      S_ch4        S_IC  ...       X_fa       X_c4      X_pro  \
# 1  0.000009  41.519089  560.017463  ...  10.445721  79.738308  40.711087
# 2  0.000010  38.465477  548.350371  ...  10.773041  81.517631  40.423545
# 3  0.000026  41.033542  529.887684  ...  11.974169  80.984802  34.751500
# 4  0.000022  40.706199  533.766835  ...  12.133200  85.457032  34.227188
# 5  0.000008  39.656685  558.607013  ...   9.660221  75.435038  40.439152
#
#          X_ac       X_h2         X_I   S_cat   S_an          H2O  \
# ...
