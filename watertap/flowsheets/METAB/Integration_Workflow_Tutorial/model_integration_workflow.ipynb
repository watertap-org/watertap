# %% [markdown]
# # Workflow Demo
#
# This is a demo and case study of the model integration workflow to connect external models

# %% [markdown]
# # Step 1 Input Space Generation

# %%
from Input_space_generation import create_samples
path = "./results_100/"
input_data_csv_file =  path + "input_data.csv"
input_var_info = {
        "inf_fr": (5000,10000),  # bounds5, 10
        "temp": (22, 35),
        "hrt": (1, 12),
    }

create_samples(method="LHS", input_var_info=input_var_info, sample_numbers=200, csv_file =input_data_csv_file )
# Out:
# Sampling type:  creation
#
# <class 'list'>
# Sample file "./results_100/input_data.csv" has been created successfully.

# %% [markdown]
# # Step 2  Model Evaluation

# %%
from model_evaluation import get_input_data, run_model, export_output_data   
path = "./results_100/" 
input_data_csv_file =  path + "input_data.csv"
input_data = get_input_data(filename=input_data_csv_file)
output_data = run_model(input_data)
output_data_csv_file = path + "output_data.csv"
export_output_data(output_data,filename=output_data_csv_file)
# Out:
# All impact indicators have been removed from the registry.
# All impact items have been removed from the registry.
# c:\Users\Maojian\anaconda3\envs\qsdsan\lib\site-packages\qsdsan\_process.py:1033: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ID = proc[0]
# c:\Users\Maojian\anaconda3\envs\qsdsan\lib\site-packages\qsdsan\_process.py:1033: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ID = proc[0]
# ...

# %% [markdown]
# ## Step 3 Surrogate model training

# %%
import surrogate_model_generator as s3

# %%
feed_data, input_data, output_data = s3.get_data()
output_data = s3.outputs_selections(output_data)

s3.gen_surrogate_model(
        tool="idaes",
        method="rbf",  # kri, poly,rbf,alamo
        feed_data=None,
        input_data=input_data,
        output_data=output_data,
    )
# Out:
#          S_su      S_aa       S_fa       S_va       S_bu      S_pro  \
# 0    0.731084  0.752787  20.490541   1.254585   1.590597   1.766505
# 1    0.790039  0.802502  21.046698   1.360776   1.724301   1.970121
# 2    2.440719  1.912096  29.209465   3.663656   4.753397   5.722872
# 3    1.969023  1.636827  27.625613   3.122116   4.006898   5.012716
# 4    0.622173  0.657064  19.328076   1.053645   1.337960   1.407006
# 5    1.244645  1.156377  24.441553   2.113990   2.680350   3.613684
# 6    0.784747  0.798338  21.000747   1.351854   1.713115   1.952380
# 7    0.956248  0.938026  22.460977   1.650933   2.090797   2.579171
# 8    0.660998  0.691803  19.764860   1.126058   1.428955   1.532264
# 9    3.376200  2.412174  32.427757   4.649321   6.167541   7.030911
# 10   1.654986  1.439229  26.435034   2.717477   3.465788   4.486764
# 11   4.510599  2.966621  36.718576   5.861150   7.949593   8.579484
# 12   1.929474  1.612074  27.480421   3.072179   3.939340   4.947409
# ...
