# %% [markdown]
# # Model Intergation Workflow Demo
#
# This notebook provides a **demonstration and case study of the model integration workflow**, showing how to connect **external models**—such as pilot-scale experimental data or rigorous process simulators—into WaterTAP.
#
# The workflow illustrates how surrogate modeling can bridge detailed models with **system-scale analysis**, enabling:
# - Technology performance screening
# - Process integration and plant-wide optimization
# - Techno-economic and market participation assessments,
#   which are **enabled capabilities within the WaterTAP and IDAES ecosystem**.
#
# **Example Case:**
# In this demonstration, we integrate the **Modular Encapsulated Two-Stage Anaerobic Biological (METAB) system**. The workflow was implemented to connect:
# - **Benchmark Simulation Model in WaterTAP**
# - **Rigorous METAB process model** developed in the study by:
#
# > Zhang, X., Arnold, W. A., Wright, N., Novak, P. J., & Guest, J. S. (2024). *Prioritization of early-stage research and development of a hydrogel-encapsulated anaerobic technology for distributed treatment of high strength organic wastewater.* Environmental Science & Technology, 58(44), 19651–19665.
#
# The model was implemented on the external modeling platform [QSDsan](https://qsdsan.com/) (Quantitative Sustainable Design for Sanitation & Resource Recovery Systems), an open-source platform that integrates system design, process modeling & simulation, techno-economic analysis, and life-cycle assessment.
#
# This example illustrates how external models can be systematically integrated into WaterTAP to enable **system-scale evaluation, optimization, and techno-economic analysis** of novel wastewater treatment technologies.

# %% [markdown]
# ![Easy Five-Step Workflow: Variables --> Input Space --> Model Runs --> Surrogate --> Selection](model_integration_workflow_steps.png)

# %% [markdown]
# ## Step 1: Define Input Variables
#
# The first step in the workflow is to **select the key operating and design variables** that will define the input space for surrogate modeling.
#
# **Example Case: METAB System**
# For the METAB system, the input variables of interest include:
# - **Influent flow rate (loading rate)** – the rate at which wastewater enters the system
# - **Operational temperature** – affects microbial activity and treatment efficiency
# - **Hydraulic Retention Time (HRT)** – the time wastewater remains in the digester, influencing conversion and biogas production
#
# **Steps:**
# - Select **key operating/design variables** relevant to system performance
# - Establish **bounds for the operational range** based on pilot data or rigorous model knowledge
#
# These defined variables and bounds form the foundation for **input space generation** in the next step.

# %%
input_var_info = {
        "inf_fr": (5000,10000),  # Influent flow rate (loading rate), lower bounds, upper bounds
        "temp": (22, 35),  #Operational temperature
        "hrt": (1, 12),   #Hydraulic Retention Time (HRT)
    }

# %% [markdown]
# ## Step 2: Input Space Generation
#
# Once the key input variables and their bounds are defined, the next step is to **systematically generate the input space**. This ensures that the surrogate model captures the full variability of the system.
#
# **Example Case: METAB System**
# For METAB, the input variables include influent flow rate, operational temperature, and HRT. The goal is to explore combinations of these variables across their feasible ranges.
#
# **Steps:**
# - **Systematically sample operating ranges** to cover variability in the input space
# - **Methods:**
#   - Random sampling within bounds
#   - **Latin Hypercube Sampling (LHS)** – a space-filling statistical technique that divides each variable’s range into intervals and selects samples to evenly cover the multi-dimensional space
#   - Other space-filling designs, as needed
#
# **Goal:**
# - Generate a **broad and representative dataset** for surrogate model training
# - Ensure that all relevant operating conditions are considered for accurate system-level predictions
#
# This input dataset will be used in **Step 3: Model Evaluations** to generate outputs for surrogate training.

# %%
from watertap.flowsheets.METAB.input_space_generation import create_samples
import os

input_data_csv_file =  "../watertap/flowsheets/METAB/input_data.csv"

if not os.path.exists(input_data_csv_file):
    create_samples(method="LHS",                    # Latin Hypercube Sampling (LHS)
                   input_var_info=input_var_info,   # defined in step 1
                   sample_numbers=20,               # can be changed to any integer
                   csv_file =input_data_csv_file )
    
print(f"Input data space file has been generated.")
# Out:
# Input data space file has been generated.

# %% [markdown]
# ## Step 3: External Model Evaluations
#
# In this step, we **run the rigorous external models** to generate outputs for the input conditions sampled in Step 2. These outputs will form the training dataset for surrogate models.
#
# **Example Case: METAB System**
# For METAB, the external model could be the rigorous process simulation implemented in QSD-SAN. For each combination of influent flow rate, operational temperature, and HRT, the model generates outputs such as:
# - **Biogas production**
# - **Effluent flow rate and quality**
#
#
# **Steps:**
# - Run the rigorous model across all sampled input sets
# - Collect model outputs to form a **comprehensive dataset**
# - Ensure that the dataset **captures nonlinear system behavior** across the operational range
#
# This dataset will then be used in **Step 4: Surrogate Model Training**, bridging the detailed external model with the WaterTAP flowsheet for system-scale analysis.

# %%
from watertap.flowsheets.METAB.model_evaluation import get_input_data, run_model, export_output_data 
import os  
import pandas as pd
input_data_csv_file =  "../watertap/flowsheets/METAB/input_data.csv"
output_data_csv_file = "../watertap/flowsheets/METAB/output_data.csv"
if not os.path.exists(output_data_csv_file):
    input_data = get_input_data(filename=input_data_csv_file)
    output_data = run_model(input_data)
    export_output_data(output_data,
                       filename=output_data_csv_file)
print(f"Model evaluation output file has been generated.")
# Out:
# Model evaluation output file has been generated.

# %% [markdown]
# ## Step 4: Surrogate Model Training
#
# Once the training dataset from Step 3 is available, we fit **surrogate models** to approximate the behavior of the rigorous external model. Surrogates allow fast evaluations while capturing nonlinear relationships between inputs and outputs.
#
# **Example Case: METAB System**
# For METAB, the surrogates predict outputs such as biogas production, effluent quality, and energy consumption based on influent flow rate, operational temperature, and HRT.
#
# ---
#
# ### Surrogate Model Types
#
# **1. Polynomial Regression**
# Fits a polynomial equation to relate inputs $x_1, x_2, ..., x_n$ to output $y$:
#
# $$
# y = \beta_0 + \sum_{i=1}^{n} \beta_i x_i + \sum_{i=1}^{n}\sum_{j=i}^{n} \beta_{ij} x_i x_j + \epsilon
# $$
#
# - $\beta$ are coefficients, $\epsilon$ is error
# - Can include higher-order terms for nonlinearity
#
# **2. Kriging (Gaussian Process Regression)**
# Models the output as a Gaussian process:
#
# $$
# y(x) = \mu + Z(x)
# $$
#
# Covariance:
#
# $$
# \text{Cov}[Z(x_i), Z(x_j)] = \sigma^2 R(x_i, x_j), \quad
# R(x_i, x_j) = \exp\left(-\sum_{k=1}^n \theta_k |x_{ik} - x_{jk}|^2\right)
# $$
#
# - $\mu$ is the mean, $Z(x)$ is a correlated Gaussian process
# - Captures nonlinearities and provides uncertainty estimates
#
# **3. Radial Basis Function (RBF)**
# Approximates outputs as weighted sums of radial functions:
#
# $$
# y(x) = \sum_{i=1}^{N} w_i \phi(\|x - x_i\|)
# $$
#
# - $x_i$ are training points, $w_i$ are weights
# - $\phi(r)$ is a radial function, e.g., Gaussian: $\phi(r) = e^{-(\epsilon r)^2}$
#
# **4. ALAMO (Automated Learning of Algebraic Models for Optimization)**
# Constructs simple algebraic models:
#
# $$
# y = \sum_{i} c_i f_i(x)
# $$
#
# - $f_i(x)$ are linear, polynomial, exponential, or rational functions
# - ALAMO selects relevant terms to balance accuracy and simplicity
# - Produces **optimization-ready models**
#
# ---
#
# These surrogate models are **computationally efficient** and ready for validation and selection in Step 5, enabling integration into WaterTAP for system-scale analysis.

# %%
import os
import watertap.flowsheets.METAB.surrogate_model_generator as trainer
feed_data, input_data, output_data = trainer.get_data()
output_data = trainer.outputs_selections(output_data)
all_surrogte_method = ['poly','kri','rbf','alamo']
path = "../watertap/flowsheets/METAB/"
for method in all_surrogte_method:
    model_file = path + method + "_surrogate.json"
    if not os.path.exists(model_file):
        trainer.gen_surrogate_model(
                method= method,
                feed_data=None,
                input_data=input_data,
                output_data=output_data,
            )
    print("Surrogate models using " + method + " method has been generated")
print("All models are trained and ready for selection")
# Out:
# ['S_su', 'S_aa', 'S_fa', 'S_va', 'S_bu', 'S_pro', 'S_ac', 'S_h2', 'S_ch4', 'S_IC', 'S_IN', 'S_I', 'X_c', 'X_ch', 'X_pr', 'X_li', 'X_su', 'X_aa', 'X_fa', 'X_c4', 'X_pro', 'X_ac', 'X_h2', 'X_I', 'S_cat', 'S_an', 'H2O', 'VolumetricFlowrate', 'bge2_S_h2', 'bge2_S_ch4', 'bge2_S_IC', 'bge2_VolumetricFlowrate', 'bgr2_S_h2', 'bgr2_S_ch4', 'bgr2_S_IC', 'bgr2_H2O', 'bgr2_VolumetricFlowrate', 'bge1_S_h2', 'bge1_S_ch4', 'bge1_S_IC', 'bge1_VolumetricFlowrate']
#
# ===========================Polynomial Regression===============================================
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.608108
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.251895  / MSE: 0.145109  / R^2: 0.982842  / Adjusted R^2: 0.953427
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.251895  / MSE: 0.145109  / R_sq: 0.982842  / Adjusted R^2: 0.953427
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -51.064732
# (x_ 1 )^ 1      | 1.700651
# (x_ 2 )^ 1      | 7.759179
# (x_ 3 )^ 1      | -7.105714
# (x_ 1 )^ 2      | -0.041508
# (x_ 2 )^ 2      | -0.301399
# (x_ 3 )^ 2      | 0.781709
# (x_ 1 )^ 3      | -0.000324
# (x_ 2 )^ 3      | 0.003808
# (x_ 3 )^ 3      | -0.030707
# x_ 1 .x_ 2      | -0.031879
# x_ 1 .x_ 3      | -0.032603
# x_ 2 .x_ 3      | 0.035173
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:15 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_su trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.074096
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.088737  / MSE: 0.017759  / R^2: 0.990575  / Adjusted R^2: 0.974418
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.088737  / MSE: 0.017759  / R_sq: 0.990575  / Adjusted R^2: 0.974418
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -13.647884
# (x_ 1 )^ 1      | 0.518497
# (x_ 2 )^ 1      | 2.517968
# (x_ 3 )^ 1      | -2.923294
# (x_ 1 )^ 2      | 0.000888
# (x_ 2 )^ 2      | -0.098598
# (x_ 3 )^ 2      | 0.316351
# (x_ 1 )^ 3      | -0.000889
# (x_ 2 )^ 3      | 0.001257
# (x_ 3 )^ 3      | -0.012178
# x_ 1 .x_ 2      | -0.01187
# x_ 1 .x_ 3      | -0.012135
# x_ 2 .x_ 3      | 0.011687
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:16 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_aa trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 9.470952
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.988848  / MSE: 2.254959  / R^2: 0.982444  / Adjusted R^2: 0.952348
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.988848  / MSE: 2.254959  / R_sq: 0.982444  / Adjusted R^2: 0.952348
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -200.040261
# (x_ 1 )^ 1      | 7.384025
# (x_ 2 )^ 1      | 32.039278
# (x_ 3 )^ 1      | -25.922623
# (x_ 1 )^ 2      | -0.308387
# (x_ 2 )^ 2      | -1.240964
# (x_ 3 )^ 2      | 2.730576
# (x_ 1 )^ 3      | 0.005274
# (x_ 2 )^ 3      | 0.01561
# (x_ 3 )^ 3      | -0.106979
# x_ 1 .x_ 2      | -0.117714
# x_ 1 .x_ 3      | -0.10847
# x_ 2 .x_ 3      | 0.142732
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:16 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_fa trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.205606
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.154351  / MSE: 0.050987  / R^2: 0.992831  / Adjusted R^2: 0.980541
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.154351  / MSE: 0.050987  / R_sq: 0.992831  / Adjusted R^2: 0.980541
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -25.414
# (x_ 1 )^ 1      | 1.092818
# (x_ 2 )^ 1      | 4.68109
# (x_ 3 )^ 1      | -5.483003
# (x_ 1 )^ 2      | -0.023206
# (x_ 2 )^ 2      | -0.182986
# (x_ 3 )^ 2      | 0.585024
# (x_ 1 )^ 3      | -0.000457
# (x_ 2 )^ 3      | 0.002327
# (x_ 3 )^ 3      | -0.022355
# x_ 1 .x_ 2      | -0.020989
# x_ 1 .x_ 3      | -0.021268
# x_ 2 .x_ 3      | 0.021643
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:16 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_va trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.372773
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.210170  / MSE: 0.093035  / R^2: 0.993203  / Adjusted R^2: 0.981551
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.210170  / MSE: 0.093035  / R_sq: 0.993203  / Adjusted R^2: 0.981551
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -26.795128
# (x_ 1 )^ 1      | 1.16437
# (x_ 2 )^ 1      | 5.646801
# (x_ 3 )^ 1      | -7.697663
# (x_ 1 )^ 2      | 0.027462
# (x_ 2 )^ 2      | -0.223765
# (x_ 3 )^ 2      | 0.84043
# (x_ 1 )^ 3      | -0.003559
# (x_ 2 )^ 3      | 0.002888
# (x_ 3 )^ 3      | -0.03226
# x_ 1 .x_ 2      | -0.030598
# x_ 1 .x_ 3      | -0.030697
# x_ 2 .x_ 3      | 0.027132
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:17 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_bu trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.947130
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.324885  / MSE: 0.229835  / R^2: 0.987178  / Adjusted R^2: 0.965198
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.324885  / MSE: 0.229835  / R_sq: 0.987178  / Adjusted R^2: 0.965198
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -73.99873
# (x_ 1 )^ 1      | 2.640061
# (x_ 2 )^ 1      | 11.104767
# (x_ 3 )^ 1      | -8.814653
# (x_ 1 )^ 2      | -0.138878
# (x_ 2 )^ 2      | -0.430228
# (x_ 3 )^ 2      | 0.887905
# (x_ 1 )^ 3      | 0.003421
# (x_ 2 )^ 3      | 0.005403
# (x_ 3 )^ 3      | -0.033786
# x_ 1 .x_ 2      | -0.035969
# x_ 1 .x_ 3      | -0.035665
# x_ 2 .x_ 3      | 0.048667
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:17 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_pro trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 3.690640
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.619289  / MSE: 0.878602  / R^2: 0.989913  / Adjusted R^2: 0.972622
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.619289  / MSE: 0.878602  / R_sq: 0.989913  / Adjusted R^2: 0.972622
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -90.627589
# (x_ 1 )^ 1      | 3.859687
# (x_ 2 )^ 1      | 17.625311
# (x_ 3 )^ 1      | -19.737897
# (x_ 1 )^ 2      | -0.04485
# (x_ 2 )^ 2      | -0.688544
# (x_ 3 )^ 2      | 2.126696
# (x_ 1 )^ 3      | -0.003811
# (x_ 2 )^ 3      | 0.008777
# (x_ 3 )^ 3      | -0.081527
# x_ 1 .x_ 2      | -0.078874
# x_ 1 .x_ 3      | -0.082499
# x_ 2 .x_ 3      | 0.078545
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:18 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_ac trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.000000
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.000002  / MSE: 0.000000  / R^2: 0.986690  / Adjusted R^2: 0.963873
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.000002  / MSE: 0.000000  / R_sq: 0.986690  / Adjusted R^2: 0.963873
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -0.000404
# (x_ 1 )^ 1      | 1.2e-05
# (x_ 2 )^ 1      | 6e-05
# (x_ 3 )^ 1      | -4.9e-05
# (x_ 1 )^ 2      | -0.0
# (x_ 2 )^ 2      | -2e-06
# (x_ 3 )^ 2      | 5e-06
# (x_ 1 )^ 3      | 0.0
# (x_ 2 )^ 3      | 0.0
# (x_ 3 )^ 3      | -0.0
# x_ 1 .x_ 2      | -0.0
# x_ 1 .x_ 3      | -0.0
# x_ 2 .x_ 3      | 0.0
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:18 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_h2 trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.283540
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.182005  / MSE: 0.069608  / R^2: 0.995764  / Adjusted R^2: 0.988503
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.182005  / MSE: 0.069608  / R_sq: 0.995764  / Adjusted R^2: 0.988503
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 24.509538
# (x_ 1 )^ 1      | 1.253592
# (x_ 2 )^ 1      | 5.201538
# (x_ 3 )^ 1      | -6.247435
# (x_ 1 )^ 2      | -0.027466
# (x_ 2 )^ 2      | -0.237211
# (x_ 3 )^ 2      | 0.619485
# (x_ 1 )^ 3      | 0.000241
# (x_ 2 )^ 3      | 0.003057
# (x_ 3 )^ 3      | -0.023946
# x_ 1 .x_ 2      | -0.028962
# x_ 1 .x_ 3      | -0.02616
# x_ 2 .x_ 3      | 0.044407
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:18 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_ch4 trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 2  with a cross-val error of 0.051850
# Initial Regression Model Performance:
# Order:  2  / MAE: 1.304313  / MSE: 3.302947  / R^2: 0.987474  / Adjusted R^2: 0.976200
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  2  / MAE: 1.304313  / MSE: 3.302947  / R_sq: 0.987474  / Adjusted R^2: 0.976200
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 525.754104
# (x_ 1 )^ 1      | -0.19139
# (x_ 2 )^ 1      | 0.118257
# (x_ 3 )^ 1      | 9.210475
# (x_ 1 )^ 2      | -0.189745
# (x_ 2 )^ 2      | -0.055276
# (x_ 3 )^ 2      | -0.408203
# x_ 1 .x_ 2      | 0.116009
# x_ 1 .x_ 3      | 0.019949
# x_ 2 .x_ 3      | 0.01078
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:19 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_IC trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.183395
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.117831  / MSE: 0.040625  / R^2: 0.999153  / Adjusted R^2: 0.997700
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.117831  / MSE: 0.040625  / R_sq: 0.999153  / Adjusted R^2: 0.997700
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 209.348131
# (x_ 1 )^ 1      | 0.283808
# (x_ 2 )^ 1      | -3.639369
# (x_ 3 )^ 1      | 4.864851
# (x_ 1 )^ 2      | -0.122069
# (x_ 2 )^ 2      | 0.140438
# (x_ 3 )^ 2      | -0.289088
# (x_ 1 )^ 3      | 0.007029
# (x_ 2 )^ 3      | -0.001772
# (x_ 3 )^ 3      | 0.00966
# x_ 1 .x_ 2      | 0.013642
# x_ 1 .x_ 3      | 0.003123
# x_ 2 .x_ 3      | -0.012928
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:19 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_IN trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.592655
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.197484  / MSE: 0.126981  / R^2: 0.999324  / Adjusted R^2: 0.998164
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.197484  / MSE: 0.126981  / R_sq: 0.999324  / Adjusted R^2: 0.998164
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 72.403091
# (x_ 1 )^ 1      | 0.11951
# (x_ 2 )^ 1      | -4.625518
# (x_ 3 )^ 1      | 9.278922
# (x_ 1 )^ 2      | -0.167723
# (x_ 2 )^ 2      | 0.180819
# (x_ 3 )^ 2      | -0.534999
# (x_ 1 )^ 3      | 0.010126
# (x_ 2 )^ 3      | -0.002316
# (x_ 3 )^ 3      | 0.017309
# x_ 1 .x_ 2      | 0.026511
# x_ 1 .x_ 3      | 0.004753
# x_ 2 .x_ 3      | -0.020566
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:19 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_I trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.566077
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.291096  / MSE: 0.175236  / R^2: 0.999194  / Adjusted R^2: 0.997812
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.291096  / MSE: 0.175236  / R_sq: 0.999194  / Adjusted R^2: 0.997812
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 245.599527
# (x_ 1 )^ 1      | -14.865028
# (x_ 2 )^ 1      | -9.99236
# (x_ 3 )^ 1      | -15.724217
# (x_ 1 )^ 2      | 2.163121
# (x_ 2 )^ 2      | 0.298993
# (x_ 3 )^ 2      | 1.387518
# (x_ 1 )^ 3      | -0.100381
# (x_ 2 )^ 3      | -0.002931
# (x_ 3 )^ 3      | -0.04757
# x_ 1 .x_ 2      | -0.001438
# x_ 1 .x_ 3      | -0.044306
# x_ 2 .x_ 3      | 0.022301
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:20 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_c trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.568461
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.244710  / MSE: 0.135761  / R^2: 0.986194  / Adjusted R^2: 0.962526
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.244710  / MSE: 0.135761  / R_sq: 0.986194  / Adjusted R^2: 0.962526
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -40.572019
# (x_ 1 )^ 1      | 1.329296
# (x_ 2 )^ 1      | 6.811506
# (x_ 3 )^ 1      | -7.364928
# (x_ 1 )^ 2      | 0.017247
# (x_ 2 )^ 2      | -0.267203
# (x_ 3 )^ 2      | 0.818707
# (x_ 1 )^ 3      | -0.003156
# (x_ 2 )^ 3      | 0.003413
# (x_ 3 )^ 3      | -0.032016
# x_ 1 .x_ 2      | -0.032803
# x_ 1 .x_ 3      | -0.033275
# x_ 2 .x_ 3      | 0.031744
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:20 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_ch trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 1.569355
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.406904  / MSE: 0.374975  / R^2: 0.985812  / Adjusted R^2: 0.961490
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.406904  / MSE: 0.374975  / R_sq: 0.985812  / Adjusted R^2: 0.961490
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -68.506598
# (x_ 1 )^ 1      | 2.233517
# (x_ 2 )^ 1      | 11.368515
# (x_ 3 )^ 1      | -12.179401
# (x_ 1 )^ 2      | 0.024769
# (x_ 2 )^ 2      | -0.445839
# (x_ 3 )^ 2      | 1.356044
# (x_ 1 )^ 3      | -0.005059
# (x_ 2 )^ 3      | 0.005693
# (x_ 3 )^ 3      | -0.053076
# x_ 1 .x_ 2      | -0.054427
# x_ 1 .x_ 3      | -0.05529
# x_ 2 .x_ 3      | 0.052944
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:20 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_pr trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.399643
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.204870  / MSE: 0.095353  / R^2: 0.986912  / Adjusted R^2: 0.964474
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.204870  / MSE: 0.095353  / R_sq: 0.986912  / Adjusted R^2: 0.964474
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -32.923399
# (x_ 1 )^ 1      | 1.089718
# (x_ 2 )^ 1      | 5.660245
# (x_ 3 )^ 1      | -6.23292
# (x_ 1 )^ 2      | 0.018349
# (x_ 2 )^ 2      | -0.222168
# (x_ 3 )^ 2      | 0.690724
# (x_ 1 )^ 3      | -0.002832
# (x_ 2 )^ 3      | 0.00284
# (x_ 3 )^ 3      | -0.026965
# x_ 1 .x_ 2      | -0.027581
# x_ 1 .x_ 3      | -0.027898
# x_ 2 .x_ 3      | 0.026417
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:21 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_li trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 2.438687
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.366230  / MSE: 0.517785  / R^2: 0.999632  / Adjusted R^2: 0.999001
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.366230  / MSE: 0.517785  / R_sq: 0.999632  / Adjusted R^2: 0.999001
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 599.908096
# (x_ 1 )^ 1      | -1.712089
# (x_ 2 )^ 1      | -12.104958
# (x_ 3 )^ 1      | -7.728765
# (x_ 1 )^ 2      | -0.001006
# (x_ 2 )^ 2      | 0.453369
# (x_ 3 )^ 2      | -0.609813
# (x_ 1 )^ 3      | 0.002031
# (x_ 2 )^ 3      | -0.005551
# (x_ 3 )^ 3      | 0.034562
# x_ 1 .x_ 2      | 0.045278
# x_ 1 .x_ 3      | 0.033715
# x_ 2 .x_ 3      | -0.048851
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:21 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_su trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 4  with a cross-val error of 0.104880
# Initial Regression Model Performance:
# Order:  4  / MAE: 0.053509  / MSE: 0.020976  / R^2: 0.999524  / Adjusted R^2: 0.997737
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  4  / MAE: 0.053509  / MSE: 0.020976  / R_sq: 0.999524  / Adjusted R^2: 0.997737
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -3.833253
# (x_ 1 )^ 1      | -23.712166
# (x_ 2 )^ 1      | 22.83242
# (x_ 3 )^ 1      | 4.428335
# (x_ 1 )^ 2      | 4.822933
# (x_ 2 )^ 2      | -1.259159
# (x_ 3 )^ 2      | -1.174039
# (x_ 1 )^ 3      | -0.423671
# (x_ 2 )^ 3      | 0.03045
# (x_ 3 )^ 3      | 0.084766
# (x_ 1 )^ 4      | 0.013639
# (x_ 2 )^ 4      | -0.000272
# (x_ 3 )^ 4      | -0.002209
# x_ 1 .x_ 2      | -0.005462
# x_ 1 .x_ 3      | 0.002019
# x_ 2 .x_ 3      | -0.001065
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:21 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_aa trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.007879
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.029867  / MSE: 0.002008  / R^2: 0.996477  / Adjusted R^2: 0.990438
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.029867  / MSE: 0.002008  / R_sq: 0.996477  / Adjusted R^2: 0.990438
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -5.548551
# (x_ 1 )^ 1      | 0.760616
# (x_ 2 )^ 1      | 1.601936
# (x_ 3 )^ 1      | 0.946522
# (x_ 1 )^ 2      | -0.099988
# (x_ 2 )^ 2      | -0.060349
# (x_ 3 )^ 2      | -0.15997
# (x_ 1 )^ 3      | 0.004394
# (x_ 2 )^ 3      | 0.000731
# (x_ 3 )^ 3      | 0.005453
# x_ 1 .x_ 2      | -0.000889
# x_ 1 .x_ 3      | 0.000428
# x_ 2 .x_ 3      | 0.006055
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:22 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_fa trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 2  with a cross-val error of 49.170460
# Initial Regression Model Performance:
# Order:  2  / MAE: 3.309516  / MSE: 18.766133  / R^2: 0.719996  / Adjusted R^2: 0.467993
#
# Polynomial regression performs poorly for this dataset.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  2  / MAE: 3.309516  / MSE: 18.766133  / R_sq: 0.719996  / Adjusted R^2: 0.467993
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 231.110291
# (x_ 1 )^ 1      | -18.28636
# (x_ 2 )^ 1      | -5.937237
# (x_ 3 )^ 1      | 0.657469
# (x_ 1 )^ 2      | 0.755784
# (x_ 2 )^ 2      | 0.007774
# (x_ 3 )^ 2      | -0.80491
# x_ 1 .x_ 2      | 0.314222
# x_ 1 .x_ 3      | -0.081391
# x_ 2 .x_ 3      | 0.423771
# 2026-05-15 15:48:22 [WARNING] idaes.core.surrogate.pysmo.polynomial_regression: Polynomial regression generates poor fit for the dataset
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:22 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_c4 trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 0.615311
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.341760  / MSE: 0.253909  / R^2: 0.974882  / Adjusted R^2: 0.931822
#
# Polynomial regression performs poorly for this dataset.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.341760  / MSE: 0.253909  / R_sq: 0.974882  / Adjusted R^2: 0.931822
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 140.244379
# (x_ 1 )^ 1      | -13.978609
# (x_ 2 )^ 1      | -4.883201
# (x_ 3 )^ 1      | -11.190261
# (x_ 1 )^ 2      | 1.612049
# (x_ 2 )^ 2      | 0.166557
# (x_ 3 )^ 2      | 1.453969
# (x_ 1 )^ 3      | -0.060072
# (x_ 2 )^ 3      | -0.002085
# (x_ 3 )^ 3      | -0.06427
# x_ 1 .x_ 2      | 0.010319
# x_ 1 .x_ 3      | 0.003276
# x_ 2 .x_ 3      | 0.072147
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:22 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_pro trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 3.121013
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.975409  / MSE: 1.714192  / R^2: 0.999419  / Adjusted R^2: 0.998422
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.975409  / MSE: 1.714192  / R_sq: 0.999419  / Adjusted R^2: 0.998422
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 884.182802
# (x_ 1 )^ 1      | -45.055977
# (x_ 2 )^ 1      | -53.043865
# (x_ 3 )^ 1      | -54.385626
# (x_ 1 )^ 2      | 6.942427
# (x_ 2 )^ 2      | 1.730697
# (x_ 3 )^ 2      | 4.804007
# (x_ 1 )^ 3      | -0.335987
# (x_ 2 )^ 3      | -0.018313
# (x_ 3 )^ 3      | -0.152015
# x_ 1 .x_ 2      | -0.055548
# x_ 1 .x_ 3      | -0.085494
# x_ 2 .x_ 3      | -0.047042
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:23 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_ac trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 2.252624
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.387042  / MSE: 0.473401  / R^2: 0.954056  / Adjusted R^2: 0.875295
#
# Polynomial regression performs poorly for this dataset.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.387042  / MSE: 0.473401  / R_sq: 0.954056  / Adjusted R^2: 0.875295
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | -163.201632
# (x_ 1 )^ 1      | 9.233933
# (x_ 2 )^ 1      | 26.804262
# (x_ 3 )^ 1      | -6.480127
# (x_ 1 )^ 2      | -1.331019
# (x_ 2 )^ 2      | -0.95728
# (x_ 3 )^ 2      | 0.560083
# (x_ 1 )^ 3      | 0.065507
# (x_ 2 )^ 3      | 0.011052
# (x_ 3 )^ 3      | -0.028479
# x_ 1 .x_ 2      | -0.013251
# x_ 1 .x_ 3      | -0.022977
# x_ 2 .x_ 3      | 0.089075
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:23 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_h2 trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 3  with a cross-val error of 1.096708
# Initial Regression Model Performance:
# Order:  3  / MAE: 0.290966  / MSE: 0.242791  / R^2: 0.998264  / Adjusted R^2: 0.995289
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  3  / MAE: 0.290966  / MSE: 0.242791  / R_sq: 0.998264  / Adjusted R^2: 0.995289
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 433.368278
# (x_ 1 )^ 1      | -15.292983
# (x_ 2 )^ 1      | -38.428197
# (x_ 3 )^ 1      | 24.589942
# (x_ 1 )^ 2      | 2.496719
# (x_ 2 )^ 2      | 1.361696
# (x_ 3 )^ 2      | -2.262035
# (x_ 1 )^ 3      | -0.122876
# (x_ 2 )^ 3      | -0.015422
# (x_ 3 )^ 3      | 0.080016
# x_ 1 .x_ 2      | -0.048766
# x_ 1 .x_ 3      | -0.015429
# x_ 2 .x_ 3      | -0.132685
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:23 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_I trained successfully
#
# ===========================Polynomial Regression===============================================
#
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# No iterations will be run.
# Default parameter estimation method is used.
# Parameter estimation method:  pyomo
#
# max_fraction_training_samples set at  0.5
# Number of adaptive samples (no_adaptive_samples) set at  4
# Maximum number of iterations (Max_iter) set at:  0
#
# Initial surrogate model is of order 2  with a cross-val error of 0.000000
# Initial Regression Model Performance:
# Order:  2  / MAE: 0.000047  / MSE: 0.000000  / R^2: 1.000000  / Adjusted R^2: 1.000000
#
# Polynomial regression generates a good surrogate model for the input data.
#
# -------------------------------------------------
# -------------------------------------------------
# Best solution found:
# Order:  2  / MAE: 0.000047  / MSE: 0.000000  / R_sq: 1.000000  / Adjusted R^2: 1.000000
#
# ------------------------------------------------------------
# The final coefficients of the regression terms are:
#
# k               | 0.027381
# (x_ 1 )^ 1      | 0.992917
# (x_ 2 )^ 1      | -0.001932
# (x_ 3 )^ 1      | -3.2e-05
# (x_ 1 )^ 2      | 7e-06
# (x_ 2 )^ 2      | 3.4e-05
# (x_ 3 )^ 2      | 2e-06
# x_ 1 .x_ 2      | 0.00029
# x_ 1 .x_ 3      | -5e-06
# x_ 2 .x_ 3      | 2e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:24 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output VolumetricFlowrate trained successfully
# Surrogate models using poly method has been generated
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 5.53639770e-03 9.23647333e+00]
# Mean: [[10.70790763]]
# Regularization parameter: 1.000000000001e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:28 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_su trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 5.37924229e-03 8.01124093e+00]
# Mean: [[5.05286218]]
# Regularization parameter: 1e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:28 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_aa trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 8.19813737e-03 8.85052738e+00]
# Mean: [[56.30165685]]
# Regularization parameter: 1e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:28 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_fa trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 1.86933013e-02 7.27114808e+00]
# Mean: [[8.32031177]]
# Regularization parameter: 2.132028142995889e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:29 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_va trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 2.75648769e-02 7.42089483e+00]
# Mean: [[10.44565483]]
# Regularization parameter: 3.5098568787264584e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:29 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_bu trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 9.84306828e-03 1.06841419e+01]
# Mean: [[13.22266926]]
# Regularization parameter: 1e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:29 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_pro trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.18358084e-03 4.55744755e-03 8.24843266e+00]
# Mean: [[44.242728]]
# Regularization parameter: 1.000000000001e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:29 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_ac trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 2.18555975e-02 1.35623316e+01]
# Mean: [[5.3980842e-05]]
# Regularization parameter: 1e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:29 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_h2 trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 1.06800473e-01 1.93080234e+00]
# Mean: [[53.69952001]]
# Regularization parameter: 8.285271852057075e-05
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:30 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_ch4 trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 6.85353912e-02 1.11307458e+00]
# Mean: [[502.78933744]]
# Regularization parameter: 0.000671484674079611
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:30 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_IC trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 1.00000000e-03 6.41833468e+00]
# Mean: [[193.19818819]]
# Regularization parameter: 2.761837049468363e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:30 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_IN trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 1.00000000e-03 6.88257202e+00]
# Mean: [[62.33618117]]
# Regularization parameter: 1.000000000001e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:30 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output S_I trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 1.00000000e-03 6.93890655e+00]
# Mean: [[69.96615712]]
# Regularization parameter: 1.000000000001e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:30 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_c trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 5.42915813e-03 8.55034881e+00]
# Mean: [[11.14735216]]
# Regularization parameter: 1e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:31 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_ch trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 5.52090067e-03 8.59467152e+00]
# Mean: [[18.06653066]]
# Regularization parameter: 1e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:31 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_pr trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [3.26613003e-03 7.84323366e-03 7.06684604e+00]
# Mean: [[9.03114809]]
# Regularization parameter: 1.8009747720926228e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:31 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_li trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 1.00000000e-03 6.19285366e+00]
# Mean: [[406.06357571]]
# Regularization parameter: 4.0916385445191605e-05
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:31 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_su trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 1.00000000e-03 1.83387896e+00]
# Mean: [[96.30852791]]
# Regularization parameter: 0.0005890828527055834
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:32 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_aa trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 1.49310204e-01 3.29808333e+00]
# Mean: [[10.68707743]]
# Regularization parameter: 8.005079129309173e-05
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:32 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_fa trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.0000000e-03 1.0000000e-03 1.0153018e+02]
# Mean: [[78.82040167]]
# Regularization parameter: 1e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:32 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_c4 trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Optimizing kriging parameters using L-BFGS-B algorithm...
#
# Final results
# ================
# Theta: [1.00000000e-03 1.15852472e-01 2.01757956e+01]
# Mean: [[40.83362416]]
# Regularization parameter: 1e-06
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:32 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_pro trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# ...
# 0    |     1    |     1.681903415309445    |     3022.2174484472084    |     6.710670793379966e-13    |     21.902210745128507    |     4.863267731886835e-15
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:38 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_pro trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Default parameter estimation method is used.
#
# Parameter estimation method:  algebraic
# Basis function:  cubic
# Regularization done:  True
# ===========================================================================================================
# 0    |     1e-05    |     0.24452547827740456    |     3022.2174484472084    |     6.710670793379966e-13    |     3013.721264139547    |     6.691805474500317e-13
# 0    |     2e-05    |     0.24449576574398083    |     3022.2174484472084    |     6.710670793379966e-13    |     3005.2727312975267    |     6.673045963129291e-13
# 0    |     5e-05    |     0.24440897499005598    |     3022.2174484472084    |     6.710670793379966e-13    |     2980.209066160658    |     6.617393446896398e-13
# 0    |     7.5e-05    |     0.24433928223930468    |     3022.2174484472084    |     6.710670793379966e-13    |     2959.6399281769573    |     6.571720785724005e-13
# 0    |     0.0001    |     0.24427192182310287    |     3022.2174484472084    |     6.710670793379966e-13    |     2939.352870673013    |     6.526674469038458e-13
# 0    |     0.0002    |     0.24402471685506472    |     3022.2174484472084    |     6.710670793379966e-13    |     2860.9124918675107    |     6.352501839818082e-13
# 0    |     0.0005    |     0.24347062446595538    |     3022.2174484472084    |     6.710670793379966e-13    |     2648.856100399924    |     5.881642063165602e-13
# 0    |     0.00075    |     0.24318611816060276    |     3022.2174484472084    |     6.710670793379966e-13    |     2494.766555573746    |     5.539494542125535e-13
# 0    |     0.001    |     0.2430298026326286    |     3022.2174484472084    |     6.710670793379966e-13    |     2357.6249396734274    |     5.23497898291187e-13
# 0    |     0.002    |     0.24328812284219603    |     3022.2174484472084    |     6.710670793379966e-13    |     1932.6992655137801    |     4.291454448499055e-13
# 0    |     0.005    |     0.2478441111505577    |     3022.2174484472084    |     6.710670793379966e-13    |     1254.5904073699344    |     2.7857503134719117e-13
# 0    |     0.0075    |     0.25314461398599475    |     3022.2174484472084    |     6.710670793379966e-13    |     970.8691872181574    |     2.1557626510974202e-13
# 0    |     0.01    |     0.2589184633863435    |     3022.2174484472084    |     6.710670793379966e-13    |     791.8732931789393    |     1.7583119253460107e-13
# 0    |     0.02    |     0.28357619188175226    |     3022.2174484472084    |     6.710670793379966e-13    |     455.98851068844215    |     1.0124978870616855e-13
# 0    |     0.05    |     0.361359522703715    |     3022.2174484472084    |     6.710670793379966e-13    |     201.07380129927543    |     4.464735277027186e-14
# 0    |     0.075    |     0.43012069407506054    |     3022.2174484472084    |     6.710670793379966e-13    |     137.39332160458434    |     3.05074458150277e-14
# 0    |     0.1    |     0.5056764890550465    |     3022.2174484472084    |     6.710670793379966e-13    |     104.4627010504827    |     2.3195379184156086e-14
# 0    |     0.2    |     1.0010014678139012    |     3022.2174484472084    |     6.710670793379966e-13    |     53.63256121925274    |     1.190882086704653e-14
# 0    |     0.5    |     2.496998802387117    |     3022.2174484472084    |     6.710670793379966e-13    |     320.89176806154575    |     7.12522858629207e-14
# 0    |     0.75    |     1.186548471038493    |     3022.2174484472084    |     6.710670793379966e-13    |     40.24039488647941    |     8.93516258459557e-15
# 0    |     1    |     1.4638303905730663    |     3022.2174484472084    |     6.710670793379966e-13    |     21.902210745128507    |     4.863267731886835e-15
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:38 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_ac trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Default parameter estimation method is used.
#
# Parameter estimation method:  algebraic
# Basis function:  cubic
# Regularization done:  True
# ===========================================================================================================
# 0    |     1e-05    |     0.6329467489756002    |     3022.2174484472084    |     6.710670793379966e-13    |     3013.721264139547    |     6.691805474500317e-13
# 0    |     2e-05    |     0.632622287136615    |     3022.2174484472084    |     6.710670793379966e-13    |     3005.2727312975267    |     6.673045963129291e-13
# 0    |     5e-05    |     0.631662054775807    |     3022.2174484472084    |     6.710670793379966e-13    |     2980.209066160658    |     6.617393446896398e-13
# 0    |     7.5e-05    |     0.6308766460792965    |     3022.2174484472084    |     6.710670793379966e-13    |     2959.6399281769573    |     6.571720785724005e-13
# 0    |     0.0001    |     0.6301043658077511    |     3022.2174484472084    |     6.710670793379966e-13    |     2939.352870673013    |     6.526674469038458e-13
# 0    |     0.0002    |     0.6271409561384688    |     3022.2174484472084    |     6.710670793379966e-13    |     2860.9124918675107    |     6.352501839818082e-13
# 0    |     0.0005    |     0.6193230895075927    |     3022.2174484472084    |     6.710670793379966e-13    |     2648.856100399924    |     5.881642063165602e-13
# 0    |     0.00075    |     0.6138390107711605    |     3022.2174484472084    |     6.710670793379966e-13    |     2494.766555573746    |     5.539494542125535e-13
# 0    |     0.001    |     0.6091154180296401    |     3022.2174484472084    |     6.710670793379966e-13    |     2357.6249396734274    |     5.23497898291187e-13
# 0    |     0.002    |     0.5956194521964004    |     3022.2174484472084    |     6.710670793379966e-13    |     1932.6992655137801    |     4.291454448499055e-13
# 0    |     0.005    |     0.5795353094052387    |     3022.2174484472084    |     6.710670793379966e-13    |     1254.5904073699344    |     2.7857503134719117e-13
# 0    |     0.0075    |     0.5765643517304395    |     3022.2174484472084    |     6.710670793379966e-13    |     970.8691872181574    |     2.1557626510974202e-13
# 0    |     0.01    |     0.5771444904762941    |     3022.2174484472084    |     6.710670793379966e-13    |     791.8732931789393    |     1.7583119253460107e-13
# 0    |     0.02    |     0.5924427604406678    |     3022.2174484472084    |     6.710670793379966e-13    |     455.98851068844215    |     1.0124978870616855e-13
# 0    |     0.05    |     0.6766757630333735    |     3022.2174484472084    |     6.710670793379966e-13    |     201.07380129927543    |     4.464735277027186e-14
# 0    |     0.075    |     0.7720892747856707    |     3022.2174484472084    |     6.710670793379966e-13    |     137.39332160458434    |     3.05074458150277e-14
# 0    |     0.1    |     0.8915409075190244    |     3022.2174484472084    |     6.710670793379966e-13    |     104.4627010504827    |     2.3195379184156086e-14
# 0    |     0.2    |     1.8342799770139884    |     3022.2174484472084    |     6.710670793379966e-13    |     53.63256121925274    |     1.190882086704653e-14
# 0    |     0.5    |     4.427589090501378    |     3022.2174484472084    |     6.710670793379966e-13    |     320.89176806154575    |     7.12522858629207e-14
# 0    |     0.75    |     1.7347309964078406    |     3022.2174484472084    |     6.710670793379966e-13    |     40.24039488647941    |     8.93516258459557e-15
# 0    |     1    |     1.666608335311348    |     3022.2174484472084    |     6.710670793379966e-13    |     21.902210745128507    |     4.863267731886835e-15
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:38 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_h2 trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Default parameter estimation method is used.
#
# Parameter estimation method:  algebraic
# Basis function:  cubic
# Regularization done:  True
# ===========================================================================================================
# 0    |     1e-05    |     0.48334876327816567    |     3022.2174484472084    |     6.710670793379966e-13    |     3013.721264139547    |     6.691805474500317e-13
# 0    |     2e-05    |     0.4833806618521758    |     3022.2174484472084    |     6.710670793379966e-13    |     3005.2727312975267    |     6.673045963129291e-13
# 0    |     5e-05    |     0.48347750354286023    |     3022.2174484472084    |     6.710670793379966e-13    |     2980.209066160658    |     6.617393446896398e-13
# 0    |     7.5e-05    |     0.48355949206046206    |     3022.2174484472084    |     6.710670793379966e-13    |     2959.6399281769573    |     6.571720785724005e-13
# 0    |     0.0001    |     0.4836426224779787    |     3022.2174484472084    |     6.710670793379966e-13    |     2939.352870673013    |     6.526674469038458e-13
# 0    |     0.0002    |     0.48398606510775477    |     3022.2174484472084    |     6.710670793379966e-13    |     2860.9124918675107    |     6.352501839818082e-13
# 0    |     0.0005    |     0.48510948702809875    |     3022.2174484472084    |     6.710670793379966e-13    |     2648.856100399924    |     5.881642063165602e-13
# 0    |     0.00075    |     0.4861355942053156    |     3022.2174484472084    |     6.710670793379966e-13    |     2494.766555573746    |     5.539494542125535e-13
# 0    |     0.001    |     0.4872290894631452    |     3022.2174484472084    |     6.710670793379966e-13    |     2357.6249396734274    |     5.23497898291187e-13
# 0    |     0.002    |     0.4921080233999384    |     3022.2174484472084    |     6.710670793379966e-13    |     1932.6992655137801    |     4.291454448499055e-13
# 0    |     0.005    |     0.509616526919379    |     3022.2174484472084    |     6.710670793379966e-13    |     1254.5904073699344    |     2.7857503134719117e-13
# 0    |     0.0075    |     0.526199553957321    |     3022.2174484472084    |     6.710670793379966e-13    |     970.8691872181574    |     2.1557626510974202e-13
# 0    |     0.01    |     0.5440316094231324    |     3022.2174484472084    |     6.710670793379966e-13    |     791.8732931789393    |     1.7583119253460107e-13
# 0    |     0.02    |     0.623824877852764    |     3022.2174484472084    |     6.710670793379966e-13    |     455.98851068844215    |     1.0124978870616855e-13
# 0    |     0.05    |     0.9120461217334049    |     3022.2174484472084    |     6.710670793379966e-13    |     201.07380129927543    |     4.464735277027186e-14
# 0    |     0.075    |     1.1991593519350823    |     3022.2174484472084    |     6.710670793379966e-13    |     137.39332160458434    |     3.05074458150277e-14
# 0    |     0.1    |     1.5380017713188903    |     3022.2174484472084    |     6.710670793379966e-13    |     104.4627010504827    |     2.3195379184156086e-14
# 0    |     0.2    |     3.9911166853972557    |     3022.2174484472084    |     6.710670793379966e-13    |     53.63256121925274    |     1.190882086704653e-14
# 0    |     0.5    |     12.206910049616045    |     3022.2174484472084    |     6.710670793379966e-13    |     320.89176806154575    |     7.12522858629207e-14
# 0    |     0.75    |     4.6285655126267    |     3022.2174484472084    |     6.710670793379966e-13    |     40.24039488647941    |     8.93516258459557e-15
# 0    |     1    |     3.587901119034615    |     3022.2174484472084    |     6.710670793379966e-13    |     21.902210745128507    |     4.863267731886835e-15
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:38 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output X_I trained successfully
# Warning: solution.pickle already exists; previous file will be overwritten.
#
# Default parameter estimation method is used.
#
# Parameter estimation method:  algebraic
# Basis function:  cubic
# Regularization done:  True
# ===========================================================================================================
# 0    |     1e-05    |     0.2297768574742993    |     3022.2174484472084    |     6.710670793379966e-13    |     3013.721264139547    |     6.691805474500317e-13
# 0    |     2e-05    |     0.22984850159692904    |     3022.2174484472084    |     6.710670793379966e-13    |     3005.2727312975267    |     6.673045963129291e-13
# 0    |     5e-05    |     0.23006306331431944    |     3022.2174484472084    |     6.710670793379966e-13    |     2980.209066160658    |     6.617393446896398e-13
# 0    |     7.5e-05    |     0.23024144612735445    |     3022.2174484472084    |     6.710670793379966e-13    |     2959.6399281769573    |     6.571720785724005e-13
# 0    |     0.0001    |     0.2304194550420539    |     3022.2174484472084    |     6.710670793379966e-13    |     2939.352870673013    |     6.526674469038458e-13
# 0    |     0.0002    |     0.2311278714576698    |     3022.2174484472084    |     6.710670793379966e-13    |     2860.9124918675107    |     6.352501839818082e-13
# 0    |     0.0005    |     0.2332213174496716    |     3022.2174484472084    |     6.710670793379966e-13    |     2648.856100399924    |     5.881642063165602e-13
# 0    |     0.00075    |     0.23493386349319262    |     3022.2174484472084    |     6.710670793379966e-13    |     2494.766555573746    |     5.539494542125535e-13
# 0    |     0.001    |     0.23662144597441678    |     3022.2174484472084    |     6.710670793379966e-13    |     2357.6249396734274    |     5.23497898291187e-13
# 0    |     0.002    |     0.24317736563865947    |     3022.2174484472084    |     6.710670793379966e-13    |     1932.6992655137801    |     4.291454448499055e-13
# 0    |     0.005    |     0.2617694219803322    |     3022.2174484472084    |     6.710670793379966e-13    |     1254.5904073699344    |     2.7857503134719117e-13
# 0    |     0.0075    |     0.27665524496144234    |     3022.2174484472084    |     6.710670793379966e-13    |     970.8691872181574    |     2.1557626510974202e-13
# 0    |     0.01    |     0.2912774675187757    |     3022.2174484472084    |     6.710670793379966e-13    |     791.8732931789393    |     1.7583119253460107e-13
# 0    |     0.02    |     0.3489283671043937    |     3022.2174484472084    |     6.710670793379966e-13    |     455.98851068844215    |     1.0124978870616855e-13
# 0    |     0.05    |     0.5284147267198813    |     3022.2174484472084    |     6.710670793379966e-13    |     201.07380129927543    |     4.464735277027186e-14
# 0    |     0.075    |     0.6965660601338961    |     3022.2174484472084    |     6.710670793379966e-13    |     137.39332160458434    |     3.05074458150277e-14
# 0    |     0.1    |     0.8913627250771536    |     3022.2174484472084    |     6.710670793379966e-13    |     104.4627010504827    |     2.3195379184156086e-14
# 0    |     0.2    |     2.278929040391021    |     3022.2174484472084    |     6.710670793379966e-13    |     53.63256121925274    |     1.190882086704653e-14
# 0    |     0.5    |     6.726248259817293    |     3022.2174484472084    |     6.710670793379966e-13    |     320.89176806154575    |     7.12522858629207e-14
# 0    |     0.75    |     2.6774133528662047    |     3022.2174484472084    |     6.710670793379966e-13    |     40.24039488647941    |     8.93516258459557e-15
# 0    |     1    |     2.430770352531699    |     3022.2174484472084    |     6.710670793379966e-13    |     21.902210745128507    |     4.863267731886835e-15
#
# Results saved in  solution.pickle
# 2026-05-15 15:48:38 [INFO] idaes.core.surrogate.pysmo_surrogate: Model for output VolumetricFlowrate trained successfully
# Surrogate models using rbf method has been generated
# Surrogate models using alamo method has been generated
# All models are trained and ready for selection

# %% [markdown]
# # Step 5: Performance Estimation & Model Selection
#
# After training surrogate models in Step 4, the next step is to **validate their accuracy** and select the best-performing model for system-scale integration.
#
# **Example Case: METAB System**
# For METAB, surrogate models predict outputs like biogas production, effluent quality, and energy consumption. These predictions are compared against a **withheld test dataset** (data not used in training) to evaluate model performance.
#
# **Steps:**
# - **Validate surrogate accuracy** using metrics such as:
#   - **R² (Coefficient of Determination)** – indicates how well the model explains variance in the data
#   - **RMSE (Root Mean Squared Error)** – measures the average prediction error
#   - **Parity plots** – visualize predicted vs. actual values for each output
#
# - **Select the best-performing surrogate model** based on these metrics
# - The selected surrogate is then **ready to integrate** into WaterTAP for system-level analysis, optimization, and techno-economic evaluation
#
# **Outcome:**
# A computationally efficient surrogate model that faithfully represents the external rigorous model and can be used for **plant-scale simulations and decision-making**.

# %%
from watertap.flowsheets.METAB.performance_estimation import display_performance
display_performance( method="poly",  
                        path = "../watertap/flowsheets/METAB/",)
# Out:
#    Predicted Variables       R^2  Adjusted R^2       MAE           MSE
# 1                 S_su  0.982842      0.953427  0.251895  1.451095e-01
# 2                 S_aa  0.990575      0.974418  0.088737  1.775902e-02
# 3                 S_fa  0.982444      0.952348  0.988848  2.254959e+00
# 4                 S_va  0.992831      0.980541  0.154351  5.098712e-02
# 5                 S_bu  0.993203      0.981551  0.210170  9.303517e-02
# 6                S_pro  0.987178      0.965198  0.324885  2.298348e-01
# 7                 S_ac  0.989913      0.972622  0.619289  8.786020e-01
# 8                 S_h2  0.986690      0.963873  0.000002  6.255281e-12
# 9                S_ch4  0.995764      0.988503  0.182005  6.960779e-02
# 10                S_IC  0.987474      0.976200  1.304313  3.302947e+00
# 11                S_IN  0.999153      0.997700  0.117831  4.062539e-02
# 12                 S_I  0.999324      0.998164  0.197484  1.269807e-01
# 13                 X_c  0.999194      0.997812  0.291096  1.752361e-01
# 14                X_ch  0.986194      0.962526  0.244710  1.357607e-01
# 15                X_pr  0.985812      0.961490  0.406904  3.749745e-01
# 16                X_li  0.986912      0.964474  0.204870  9.535300e-02
# 17                X_su  0.999632      0.999001  0.366230  5.177848e-01
# 18                X_aa  0.999524      0.997737  0.053509  2.097600e-02
# 19                X_fa  0.996477      0.990438  0.029867  2.007681e-03
# 20                X_c4  0.719996      0.467993  3.309516  1.876613e+01
# 21               X_pro  0.974882      0.931822  0.341760  2.539085e-01
# 22                X_ac  0.999419      0.998422  0.975409  1.714192e+00
# 23                X_h2  0.954056      0.875295  0.387042  4.734013e-01
# 24                 X_I  0.998264      0.995289  0.290966  2.427914e-01
# 25  VolumetricFlowrate  1.000000      1.000000  0.000047  3.134991e-09

# %%
from watertap.flowsheets.METAB.performance_estimation import display_plot
path = "../watertap/flowsheets/METAB/"
display_plot(method="poly", path=path)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="../watertap/flowsheets/METAB/poly_parity.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
